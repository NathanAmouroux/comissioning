# %%
import sys
sys.path.append('../vizualize_calib/')
import vizualize_calib

# %%
get_viz = vizualize_calib.vizualize(collection = 'LATISS/runs/AUXTEL_DRP_IMAGING_2023-11A-10A-09AB-08ABC-07AB-05AB/w_2023_46/PREOPS-4553', detector = 0, repo = 'embargo', exp = 'LATISS', is_chained=True)

# %% [markdown]
# outpath and inpath optinal but needs to be changed with notebooks

# %%
get_viz.plot_calib(calib = "flat-g", outpath = '/sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/', inpath = "/sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/")
# Out:
# Found flat-g. Its name is LATISS/calib/DM-40904//flat-g
# Data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-g_0_data.pkl

# %%
get_viz = vizualize_calib.vizualize(collection = 'LATISS/runs/AUXTEL_DRP_IMAGING_20230509_20240201/w_2024_05/PREOPS-4871')

# %%
get_viz.plot_calib_lot(outpath = '/sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/', inpath = "/sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/")
# Out:
# Found flat-i. Its name is LATISS/calib/DM-41786/flat-i
# Data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-i_0_data.pkl
# Found flat-z. Its name is LATISS/calib/DM-41760/flat-z
# Data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-z_0_data.pkl
# Found flat-y. Its name is LATISS/calib/DM-41760/flat-y
# Data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-y_0_data.pkl
# Found flat-g. Its name is LATISS/calib/DM-40904//flat-g
# Data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-g_0_data.pkl
# Found flat-r. Its name is LATISS/calib/DM-40904//flat-r
# Data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-r_0_data.pkl
# ...
