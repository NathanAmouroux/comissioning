# %%
import vizualize_calib

# %%
get_viz = vizualize_calib.vizualize(collection = 'LATISS/runs/AUXTEL_DRP_IMAGING_2023-11A-10A-09AB-08ABC-07AB-05AB/w_2023_46/PREOPS-4553', calib = "flat-i")

# %%
get_viz.plot_calib(collection = 'LATISS/runs/AUXTEL_DRP_IMAGING_2023-11A-10A-09AB-08ABC-07AB-05AB/w_2023_46/PREOPS-4553', calib = "flat-g", outpath = '/sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/', inpath = "/sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/")
# Out:
# Found flat-g. Its name is LATISS/calib/DM-40904//flat-g
# data outpath will be /sdf/data/rubin/user/amouroux/comissioning/module_calibration_collections/save_calibrations_data/flat-g_0_data.pkl

# %%
calibs = ["flat-i", "flat-g", "dark"]

# %%
numbers = [1,2,3,4]

# %%
numbers.pop(1)
# Out:
# 2

# %%
n2 = [3,1]

# %%
a, b = n2
print(a, b)
# Out:
# 3 1

# %%
[numbers.pop(numbers.index(j) for j in n2)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 [numbers.pop(numbers.index(j) for j in n2)]
#
# TypeError: 'generator' object cannot be interpreted as an integer

# %%
range_dict = {"calib_type" : ["flat", "defects", "dark", "bias", "crosstalk"], "range" : [(0.9,1.1), (0,1), (-0.1,0.1), (-4,4), (0,0.0005)]} #For plotting
ranges = [range_dict["range"][range_dict["calib_type"].index(calib.split('-')[0])] for calib in calibs]

# %%
ranges
# Out:
# [(0.9, 1.1), (0.9, 1.1), (-0.1, 0.1)]

# %%
vmin, vmax = [range[0] for range in ranges], [range[1] for range in ranges]

# %%
vmin
# Out:
# [0.9, 0.9, -0.1]

# %%
ranges[0][1]
# Out:
# 1.1
